# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float, Date

import pymysql
pymysql.install_as_MySQLdb()

import MySQLdb

# %%
Base = declarative_base()

# %%
populations = pd.read_csv("populations_final.csv")

# %%
populations.head()
# Out:
#   State      2007      2016 Percent Change  population_2016  population 2007  \
# 0    AK    1642.0    1940.0            18%         741894.0         710249.0
# 1    AL    5452.0    4111.0           -25%        4863300.0        4780127.0
# 2    AR    3836.0    2463.0           -36%        2988248.0        2915958.0
# 3    AZ   14646.0    9707.0           -34%        6931071.0        6392307.0
# 4    CA  138986.0  118142.0           -15%       39250017.0       37254503.0
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN

# %%
populations = populations[['State', '2007', '2016', 'Percent Change', 'population_2016', 'population 2007']]

# %%
weather = pd.read_csv("data_sets/states_weather.csv")

# %%
weather.head()
# Out:
#         State  avg_temp_F  prcp_in  days_snowed  in_snow
# 0     Alabama        62.8     58.3          0.8      1.6
# 1      Alaska        26.6     22.5         48.0     74.5
# 2     Arizona        60.3     13.6          0.3      0.3
# 3    Arkansas        60.4     50.6          3.8      5.2
# 4  California        59.4     22.2          0.0      0.0

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %%
weather["abbreviation"] = ""

# %%
for index, row in weather.iterrows():
    state = row["State"]
    abbr = us_state_abbrev[state]
    weather.set_value(index, "abbreviation", abbr)

# %%
weather
# Out:
#              State  avg_temp_F  prcp_in  days_snowed  in_snow abbreviation
# 0          Alabama        62.8     58.3          0.8      1.6           AL
# 1           Alaska        26.6     22.5         48.0     74.5           AK
# 2          Arizona        60.3     13.6          0.3      0.3           AZ
# 3         Arkansas        60.4     50.6          3.8      5.2           AR
# 4       California        59.4     22.2          0.0      0.0           CA
# 5         Colorado        45.1     15.9         19.1     19.1           CO
# 6      Connecticut        49.0     50.3         20.1     40.5           CT
# 7         Delaware        55.3     45.7         11.8     20.2           DE
# 8          Florida        70.7     54.5          0.0      0.0           FL
# 9          Georgia        63.5     50.7          0.7      0.7           GA
# 10          Hawaii        70.0     63.7          0.0      0.0           HI
# ...

# %%
df = weather.merge(populations, how='outer', left_on="abbreviation", right_on="State")

# %%
df.head()
# Out:
#       State_x  avg_temp_F  prcp_in  days_snowed  in_snow abbreviation State_y  \
# 0     Alabama        62.8     58.3          0.8      1.6           AL      AL
# 1      Alaska        26.6     22.5         48.0     74.5           AK      AK
# 2     Arizona        60.3     13.6          0.3      0.3           AZ      AZ
# 3    Arkansas        60.4     50.6          3.8      5.2           AR      AR
# 4  California        59.4     22.2          0.0      0.0           CA      CA
#
#        2007      2016 Percent Change  population_2016  population 2007
# 0    5452.0    4111.0           -25%        4863300.0        4780127.0
# 1    1642.0    1940.0            18%         741894.0         710249.0
# 2   14646.0    9707.0           -34%        6931071.0        6392307.0
# 3    3836.0    2463.0           -36%        2988248.0        2915958.0
# 4  138986.0  118142.0           -15%       39250017.0       37254503.0

# %%
del df['State_y']

# %%
df.head()
# Out:
#       State_x  avg_temp_F  prcp_in  days_snowed  in_snow abbreviation  \
# 0     Alabama        62.8     58.3          0.8      1.6           AL
# 1      Alaska        26.6     22.5         48.0     74.5           AK
# 2     Arizona        60.3     13.6          0.3      0.3           AZ
# 3    Arkansas        60.4     50.6          3.8      5.2           AR
# 4  California        59.4     22.2          0.0      0.0           CA
#
#        2007      2016 Percent Change  population_2016  population 2007
# 0    5452.0    4111.0           -25%        4863300.0        4780127.0
# 1    1642.0    1940.0            18%         741894.0         710249.0
# 2   14646.0    9707.0           -34%        6931071.0        6392307.0
# 3    3836.0    2463.0           -36%        2988248.0        2915958.0
# 4  138986.0  118142.0           -15%       39250017.0       37254503.0

# %%
df.rename(columns={'2007': 'homeless_pop_2007', '2016': 'homeless_pop_2016'}, inplace=True)

# %%
df.head()
# Out:
#         State  avg_temp_F  prcp_in  days_snowed  in_snow abbreviation  \
# 0     Alabama        62.8     58.3          0.8      1.6           AL
# 1      Alaska        26.6     22.5         48.0     74.5           AK
# 2     Arizona        60.3     13.6          0.3      0.3           AZ
# 3    Arkansas        60.4     50.6          3.8      5.2           AR
# 4  California        59.4     22.2          0.0      0.0           CA
#
#    homelss_pop_2007  homeless_pop_2016 Percent Change  population_2016  \
# 0            5452.0             4111.0           -25%        4863300.0
# 1            1642.0             1940.0            18%         741894.0
# 2           14646.0             9707.0           -34%        6931071.0
# 3            3836.0             2463.0           -36%        2988248.0
# 4          138986.0           118142.0           -15%       39250017.0
#
#    population 2007
# 0        4780127.0
# 1         710249.0
# 2        6392307.0
# 3        2915958.0
# ...

# %%
del df["Percent Change"]

# %%
df.to_csv("weather_homeless.csv")

# %%
class Homeless(Base):
    __tablename__ = 'homeless'
    State = Column(String(225), primary_key=True)
    avg_temp_F = Column(Float)
    prcp_in = Column(Float)
    days_snowed = Column(Float)
    in_snowed = Column(Float)
    abbreviation = Column(String)
    homlss_pop_2007 = Column(Float)
    homlss_pop_2016 = Column(Float)
    population_2016 = Column(Float)
    population2007 = Column(Float)

# %%
engine = create_engine("mysql://zu1zgsy3y1g0iekj:rh9cs673b90rmmxg@ffn96u87j5ogvehy.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/bsgneuqtl9m07jcc")

# %%
Base.metadata.create_all(engine)
# Out:
# ---------------------------------------------------------------------------
# CompileError                              Traceback (most recent call last)
# /Users/michaeldurst/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/compiler.py in visit_create_table(self, create)
#    2328                                          first_pk=column.primary_key
# -> 2329                                          and not first_pk)
#    2330                 if processed is not None:
#
# /Users/michaeldurst/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/compiler.py in process(self, obj, **kwargs)
#     241     def process(self, obj, **kwargs):
# --> 242         return obj._compiler_dispatch(self, **kwargs)
#     243
#
# /Users/michaeldurst/anaconda/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/sql/visitors.py in _compiler_dispatch(self, visitor, **kw)
#      80                 else:
# ---> 81                     return meth(self, **kw)
# ...

# %%
conn = engine.connect()

# %%
var = (conn.execute("show tables"))

# %%
db= MySQLdb.connect("ffn96u87j5ogvehy.cbetxkdyhwsb.us-east-1.rds.amazonaws.com", "zu1zgsy3y1g0iekj", "rh9cs673b90rmmxg", "bsgneuqtl9m07jcc")

cursor= db.cursor()

result = cursor.fetchall()

for i in range(len(result)):
    print(result[i])
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-72-edd025e40b52> in <module>()
#       3 cursor= db.cursor()
#       4
# ----> 5 result = cursor.fetchall()
#       6
#       7 for i in range(len(result)):
#
# /Users/michaeldurst/anaconda/envs/PythonData/lib/python3.6/site-packages/pymysql/cursors.py in fetchall(self)
#     293     def fetchall(self):
#     294         """Fetch all the rows"""
# --> 295         self._check_executed()
#     296         if self._rows is None:
#     297             return ()
#
# /Users/michaeldurst/anaconda/envs/PythonData/lib/python3.6/site-packages/pymysql/cursors.py in _check_executed(self)
#      73     def _check_executed(self):
#      74         if not self._executed:
# ---> 75             raise err.ProgrammingError("execute() first")
#      76
#      77     def _conv_row(self, row):
#
# ProgrammingError: execute() first

# %%
pd.df.to_sql('homeless')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-7c3cd363d11f> in <module>()
# ----> 1 pd.df.to_sql('homeless')
#
# AttributeError: module 'pandas' has no attribute 'df'
