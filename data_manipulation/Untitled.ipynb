# %%
import pandas as pd

# %%
homeless = pd.read_csv("homeless_populations.csv")

# %%
homeless
# Out:
#          Year State CoC Number  \
# 0      1/1/07    AK     AK-500
# 1      1/1/07    AK     AK-500
# 2      1/1/07    AK     AK-500
# 3      1/1/07    AK     AK-500
# 4      1/1/07    AK     AK-500
# 5      1/1/07    AK     AK-500
# 6      1/1/07    AK     AK-500
# 7      1/1/07    AK     AK-500
# 8      1/1/07    AK     AK-500
# 9      1/1/07    AK     AK-500
# 10     1/1/07    AK     AK-500
# 11     1/1/07    AK     AK-500
# 12     1/1/07    AK     AK-501
# 13     1/1/07    AK     AK-501
# 14     1/1/07    AK     AK-501
# 15     1/1/07    AK     AK-501
# 16     1/1/07    AK     AK-501
# 17     1/1/07    AK     AK-501
# 18     1/1/07    AK     AK-501
# 19     1/1/07    AK     AK-501
# 20     1/1/07    AK     AK-501
# 21     1/1/07    AK     AK-501
# 22     1/1/07    AK     AK-501
# 23     1/1/07    AK     AK-501
# 24     1/1/07    AL     AL-500
# 25     1/1/07    AL     AL-500
# 26     1/1/07    AL     AL-500
# 27     1/1/07    AL     AL-500
# 28     1/1/07    AL     AL-500
# ...
